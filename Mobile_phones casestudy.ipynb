# %%
import pandas as pd
import  matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

# %%
## load data

# %%
data= pd.read_csv('mobile_phones1.csv')
data
# Out:
#      Unnamed: 0    Brand             Model            Color Storage  Rating  \
# 0             0  SAMSUNG        Galaxy F05    Twilight Blue   64 GB     4.2
# 1             1   realme              GT 6     Fluid Silver  512 GB     4.5
# 2             2  Infinix       Note 40X 5G       Lime Green  256 GB     4.2
# 3             3    Apple    iPhone 16 Plus            Black  256 GB     4.6
# 4             4   realme         P2 Pro 5G       Eagle Grey  512 GB     4.4
# ..          ...      ...               ...              ...     ...     ...
# 331         331    REDMI            13C 5G  Starlight Black  256 GB     4.2
# 332         332    REDMI    Note-13 Pro 5G      Scarlet Red  256 GB     4.5
# 333         333    REDMI            13c 5G  Starlight Black  128 GB     4.3
# 334         334    REDMI   Note 13 Pro+ 5G    Fusion Purple  256 GB     4.3
# 335         335   realme        14 Pro+ 5G   Bikaner Purple  128 GB     4.4
#
#            RAM         ROM  Screen Size  \
# ...

# %%
## check shape
data.shape
# Out:
# (336, 16)

# %%
## data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      336 non-null    int64
#  1   Brand           336 non-null    object
#  2   Model           316 non-null    object
#  3   Color           316 non-null    object
#  4   Storage         315 non-null    object
#  5   Rating          336 non-null    float64
#  6   RAM             282 non-null    object
#  7   ROM             314 non-null    object
#  8   Screen Size     336 non-null    float64
#  9   Camera          330 non-null    object
#  10  Battery         302 non-null    object
#  11  Price           336 non-null    object
#  12  Original_price  326 non-null    object
#  13  Discount        323 non-null    object
#  14  No_of_rating    295 non-null    object
#  15  No_of_review    146 non-null    object
# dtypes: float64(2), int64(1), object(13)
# ...

# %%
## drop unwanted column
data= data.drop(columns=['Unnamed: 0'], axis = 1)
data
# Out:
#        Brand             Model            Color Storage  Rating        RAM  \
# 0    SAMSUNG        Galaxy F05    Twilight Blue   64 GB     4.2   4 GB RAM
# 1     realme              GT 6     Fluid Silver  512 GB     4.5  16 GB RAM
# 2    Infinix       Note 40X 5G       Lime Green  256 GB     4.2   8 GB RAM
# 3      Apple    iPhone 16 Plus            Black  256 GB     4.6        NaN
# 4     realme         P2 Pro 5G       Eagle Grey  512 GB     4.4  12 GB RAM
# ..       ...               ...              ...     ...     ...        ...
# 331    REDMI            13C 5G  Starlight Black  256 GB     4.2   8 GB RAM
# 332    REDMI    Note-13 Pro 5G      Scarlet Red  256 GB     4.5   8 GB RAM
# 333    REDMI            13c 5G  Starlight Black  128 GB     4.3   4 GB RAM
# 334    REDMI   Note 13 Pro+ 5G    Fusion Purple  256 GB     4.3   8 GB RAM
# 335   realme        14 Pro+ 5G   Bikaner Purple  128 GB     4.4   8 GB RAM
#
#             ROM  Screen Size  \
# 0     64 GB ROM         6.74
# ...

# %%
## missing values
data.isnull().sum()
# Out:
# Brand               0
# Model              20
# Color              20
# Storage            21
# Rating              0
# RAM                54
# ROM                22
# Screen Size         0
# Camera              6
# Battery            34
# Price               0
# Original_price     10
# Discount           13
# No_of_rating       41
# No_of_review      190
# dtype: int64

# %%
## check uniques
data.apply(pd.Series.unique)
# Out:
# Brand             [SAMSUNG, realme, Infinix, Apple, OPPO, vivo, ...
# Model             [ Galaxy F05,  GT 6,  Note 40X 5G,  iPhone 16 ...
# Color             [Twilight Blue, Fluid Silver, Lime Green, Blac...
# Storage                  [64 GB, 512 GB, 256 GB, 128 GB, 32GB, nan]
# Rating                [4.2, 4.5, 4.6, 4.4, 4.1, 4.3, 4.0, 4.7, 3.9]
# RAM               [4 GB RAM, 16 GB RAM, 8 GB RAM, nan, 12 GB RAM...
# ROM               [64 GB ROM, 512 GB ROM, 256 GB ROM, 128 GB ROM...
# Screen Size       [6.74, 6.78, 6.7, 6.67, 6.77, 6.72, 6.71, 6.5,...
# Camera            [Display50MP + 2MP | 8MP Front Camera, Display...
# Battery           [5000 mAh, 5500 mAh, nan, 5200 mAh, 5100 mAh, ...
# Price             [₹6,299, ₹37,999, ₹12,999, ₹88,999, ₹22,999, ₹...
# Original_price    [₹9,999, ₹51,999, ₹19,999, ₹99,900, ₹30,999, ₹...
# Discount          [37% off, 26% off, 35% off, 10% off, 25% off, ...
# No_of_rating      [32,002 Ratings, 3,366 Ratings, 2,948 Ratings,...
# ...

# %%
## Correct Values in columns
data['Brand']= data['Brand'].str.lower()
data['Color']= data['Color'].str.lower().fillna('unknown')
data['Storage']= data['Storage'].replace('GB','',regex=True).fillna(0).astype(int)
data['RAM']= data['RAM'].replace('GB RAM','',regex= True).fillna(0).astype(object)
data['ROM']= data['ROM'].replace('GB ROM','',regex= True).fillna(0).astype(object)
data['Battery']= data['Battery'].replace('mAh','',regex= True).fillna(0).astype(int)
data['Price']= data['Price'].str.replace('[^\d]', '', regex=True).astype(int)
data['Original_price']= data['Original_price'].str.replace('[^\d]', '', regex=True).fillna(0).astype(int)
data['Discount']= data['Discount'].replace('% off','',regex= True).fillna(0).astype(int)
data['No_of_rating']= data['No_of_rating'].replace('[^\d]','',regex= True).fillna(0).astype(int)
data['No_of_review']= data['No_of_review'].replace('[^\d]','',regex= True).fillna(0).astype(int)
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# <>:12: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# <>:12: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\dell\AppData\Local\Temp\ipykernel_15228\95347446.py:8: SyntaxWarning: invalid escape sequence '\d'
#   data['Price']= data['Price'].str.replace('[^\d]', '', regex=True).astype(int)
# C:\Users\dell\AppData\Local\Temp\ipykernel_15228\95347446.py:9: SyntaxWarning: invalid escape sequence '\d'
#   data['Original_price']= data['Original_price'].str.replace('[^\d]', '', regex=True).fillna(0).astype(int)
# C:\Users\dell\AppData\Local\Temp\ipykernel_15228\95347446.py:11: SyntaxWarning: invalid escape sequence '\d'
# ...

# %%
data
# Out:
#        Brand             Model            Color  Storage  Rating  RAM   ROM  \
# 0    samsung        Galaxy F05    twilight blue       64     4.2   4    64
# 1     realme              GT 6     fluid silver      512     4.5  16   512
# 2    infinix       Note 40X 5G       lime green      256     4.2   8   256
# 3      apple    iPhone 16 Plus            black      256     4.6    0  256
# 4     realme         P2 Pro 5G       eagle grey      512     4.4  12   512
# ..       ...               ...              ...      ...     ...  ...   ...
# 331    redmi            13C 5G  starlight black      256     4.2   8   256
# 332    redmi    Note-13 Pro 5G      scarlet red      256     4.5   8   256
# 333    redmi            13c 5G  starlight black      128     4.3   4   128
# 334    redmi   Note 13 Pro+ 5G    fusion purple      256     4.3   8   256
# 335   realme        14 Pro+ 5G   bikaner purple      128     4.4   8   128
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           336 non-null    object
#  1   Model           316 non-null    object
#  2   Color           336 non-null    object
#  3   Storage         336 non-null    int32
#  4   Rating          336 non-null    float64
#  5   RAM             336 non-null    object
#  6   ROM             336 non-null    object
#  7   Screen Size     336 non-null    float64
#  8   Camera          330 non-null    object
#  9   Battery         336 non-null    int32
#  10  Price           336 non-null    int32
#  11  Original_price  336 non-null    int32
#  12  Discount        336 non-null    int32
#  13  No_of_rating    336 non-null    int32
#  14  No_of_review    336 non-null    int32
# dtypes: float64(2), int32(7), object(6)
# memory usage: 30.3+ KB

# %%
## Derive columns
data['rear_camera'] = data['Camera'].str.split('|').str[0]
data['front_camera']= data['Camera'].str.split('|').str[1]

# %%
data['rear_camera'] = data['rear_camera'].replace('Display','',regex=True).fillna(0)
data['front_camera'] = data['front_camera'].replace('[^\d]','',regex=True).fillna(0).astype(int)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\dell\AppData\Local\Temp\ipykernel_15228\3499976604.py:2: SyntaxWarning: invalid escape sequence '\d'
#   data['front_camera'] = data['front_camera'].replace('[^\d]','',regex=True).fillna(0).astype(int)

# %%
data
# Out:
#        Brand             Model            Color  Storage  Rating  RAM   ROM  \
# 0    samsung        Galaxy F05    twilight blue       64     4.2   4    64
# 1     realme              GT 6     fluid silver      512     4.5  16   512
# 2    infinix       Note 40X 5G       lime green      256     4.2   8   256
# 3      apple    iPhone 16 Plus            black      256     4.6    0  256
# 4     realme         P2 Pro 5G       eagle grey      512     4.4  12   512
# ..       ...               ...              ...      ...     ...  ...   ...
# 331    redmi            13C 5G  starlight black      256     4.2   8   256
# 332    redmi    Note-13 Pro 5G      scarlet red      256     4.5   8   256
# 333    redmi            13c 5G  starlight black      128     4.3   4   128
# 334    redmi   Note 13 Pro+ 5G    fusion purple      256     4.3   8   256
# 335   realme        14 Pro+ 5G   bikaner purple      128     4.4   8   128
#
# ...

# %%
## recheck missing values
data.isnull().sum()
# Out:
# Brand             0
# Model             0
# Color             0
# Storage           0
# Rating            0
# RAM               0
# ROM               0
# Screen Size       0
# Battery           0
# Price             0
# Original_price    0
# Discount          0
# No_of_rating      0
# No_of_review      0
# rear_camera       0
# front_camera      0
# dtype: int64

# %%
## impute model 
data['Model']= data['Model'].fillna('unknown')

# %%
## drop camera col
data= data.drop(columns=['Camera'], axis =1)

# %%
## description of data
data.describe()
# Out:
#           Storage      Rating  Screen Size      Battery          Price  \
# count  336.000000  336.000000   336.000000   336.000000     336.000000
# mean   168.761905    4.360714     6.385734  4423.708333   25755.080357
# std    108.296069    0.151031     1.181944  1808.065928   29738.775393
# min      0.000000    3.900000     0.660000     0.000000     890.000000
# 25%    128.000000    4.300000     6.670000  5000.000000   10999.000000
# 50%    128.000000    4.400000     6.700000  5000.000000   14999.000000
# 75%    256.000000    4.400000     6.741250  5160.000000   23685.500000
# max    512.000000    4.700000     6.900000  6000.000000  177900.000000
#
#        Original_price    Discount  No_of_rating  No_of_review  front_camera
# count      336.000000  336.000000    336.000000    336.000000    336.000000
# mean     27858.351190   22.050595  21471.354167   1549.464286     11.767857
# std      28235.443539    9.911269  25164.272673   2389.735560     12.727675
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           336 non-null    object
#  1   Model           336 non-null    object
#  2   Color           336 non-null    object
#  3   Storage         336 non-null    int32
#  4   Rating          336 non-null    float64
#  5   RAM             336 non-null    object
#  6   ROM             336 non-null    object
#  7   Screen Size     336 non-null    float64
#  8   Battery         336 non-null    int32
#  9   Price           336 non-null    int32
#  10  Original_price  336 non-null    int32
#  11  Discount        336 non-null    int32
#  12  No_of_rating    336 non-null    int32
#  13  No_of_review    336 non-null    int32
#  14  rear_camera     336 non-null    object
#  15  front_camera    336 non-null    int32
# dtypes: float64(2), int32(8), object(6)
# memory usage: 31.6+ KB

# %%
data.apply(pd.Series.unique)
# Out:
# Brand             [samsung, realme, infinix, apple, oppo, vivo, ...
# Model             [ Galaxy F05,  GT 6,  Note 40X 5G,  iPhone 16 ...
# Color             [twilight blue, fluid silver, lime green, blac...
# Storage                                  [64, 512, 256, 128, 32, 0]
# Rating                [4.2, 4.5, 4.6, 4.4, 4.1, 4.3, 4.0, 4.7, 3.9]
# RAM                                   [4 , 16 , 8 , 0, 12 , 6 , 3 ]
# ROM                                 [64 , 512 , 256 , 128 , 0, 16 ]
# Screen Size       [6.74, 6.78, 6.7, 6.67, 6.77, 6.72, 6.71, 6.5,...
# Battery           [5000, 5500, 0, 5200, 5100, 6000, 5160, 5030, ...
# Price             [6299, 37999, 12999, 88999, 22999, 13999, 5899...
# Original_price    [9999, 51999, 19999, 99900, 30999, 16999, 2999...
# Discount          [37, 26, 35, 10, 25, 23, 34, 15, 20, 17, 27, 3...
# No_of_rating      [32002, 3366, 2948, 1002, 5672, 30387, 43118, ...
# No_of_review      [1845, 0, 4682, 2955, 5003, 3063, 1709, 5061, ...
# ...

# %% [markdown]
# ### Why do EDA
#
# - Model building
# - Analysis and reporting
# - Validate assumptions
# - Handling missing values
# - feature engineering
# - detecting outliers

# %%
## split into numerical and categorical 

numerical_columns= data.select_dtypes(include= ['int32','float64']).columns.tolist()
categorical_columns= data.select_dtypes(include= ['object']).columns.tolist()
categorical_columns
# Out:
# ['Brand', 'Model', 'Color', 'RAM', 'ROM', 'rear_camera']

# %%
print(numerical_columns)
print('-'*50)
print(categorical_columns)
# Out:
# ['Storage', 'Rating', 'Screen Size', 'Battery', 'Price', 'Original_price', 'Discount', 'No_of_rating', 'No_of_review', 'front_camera']
# --------------------------------------------------
# ['Brand', 'Model', 'Color', 'RAM', 'ROM', 'rear_camera']

# %% [markdown]
# ### Univariate Analysis
#
# Univariate analysis focuses on analyzing each feature in the dataset independently.
#
# - **Distribution analysis**: The distribution of each feature is examined to identify its shape, central tendency, and dispersion.
#
# - **Identifying potential issues**: Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values
#
# #### The shape of a data distribution refers to its overall pattern or form as it is represented on a graph. Some common shapes of data distributions include:
#
# - **Normal Distribution**: A symmetrical and bell-shaped distribution where the mean, median, and mode are equal and the majority of the data falls in the middle of the distribution with gradually decreasing frequencies towards the tails.
#
# - **Skewed Distribution**: A distribution that is not symmetrical, with one tail being longer than the other. It can be either positively skewed (right-skewed) or negatively skewed (left-skewed).
#
# - **Bimodal Distribution**: A distribution with two peaks or modes.
#
# - **Uniform Distribution**: A distribution where all values have an equal chance of occurring.
#
# The shape of the data distribution is important in identifying the presence of outliers, skewness, and the type of statistical tests and models that can be used for further analysis.

# %% [markdown]
# #### **Dispersion** is a statistical term used to describe the spread or variability of a set of data. It measures how far the values in a data set are spread out from the central tendency (mean, median, or mode) of the data.
#
# There are several measures of dispersion, including:
#
# - **Range**: The difference between the largest and smallest values in a data set.
#
# - **Variance**: The average of the squared deviations of each value from the mean of the data set.
#
# - **Standard Deviation**: The square root of the variance. It provides a measure of the spread of the data that is in the same units as the original data.
#
# - **Interquartile range (IQR)**: The range between the first quartile (25th percentile) and the third quartile (75th percentile) of the data.
#
# Dispersion helps to describe the spread of the data, which can help to identify the presence of outliers and skewness in the data.

# %% [markdown]
# ### Steps of doing Univariate Analysis on Numerical columns
#
# - **Descriptive Statistics**: Compute basic summary statistics for the column, such as mean, median, mode, standard deviation, range, and quartiles. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# - **Visualizations**: Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include histograms, box plots, and density plots. These visualizations provide a visual representation of the distribution of the data and can help identify skewness an outliers.
#
# - **Identifying Outliers**: Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to measurement errors, data entry errors, or legitimate differences in the data, and to decide whether to include or exclude them from the analysis.
#
# - **Skewness**: Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# - **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# ## Distribution of Data

# %%
data[numerical_columns].plot(kind= 'box',
                            subplots= True,
                            figsize=(25,35),
                            layout= (7,4))
# Out:
# Storage              Axes(0.125,0.786098;0.168478x0.0939024)
# Rating            Axes(0.327174,0.786098;0.168478x0.0939024)
# Screen Size       Axes(0.529348,0.786098;0.168478x0.0939024)
# Battery           Axes(0.731522,0.786098;0.168478x0.0939024)
# Price                Axes(0.125,0.673415;0.168478x0.0939024)
# Original_price    Axes(0.327174,0.673415;0.168478x0.0939024)
# Discount          Axes(0.529348,0.673415;0.168478x0.0939024)
# No_of_rating      Axes(0.731522,0.673415;0.168478x0.0939024)
# No_of_review         Axes(0.125,0.560732;0.168478x0.0939024)
# front_camera      Axes(0.327174,0.560732;0.168478x0.0939024)
# dtype: object

# %%
data[numerical_columns].plot(kind= 'kde',
                            subplots= True,
                            figsize=(25,35),
                            layout= (7,4))
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %%
data[numerical_columns].plot(kind= 'hist',
                            subplots= True,
                            figsize=(25,35),
                            layout= (7,4))
# Out:
# array([[<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>]],
#       dtype=object)

# %% [markdown]
# ## Univariate analysis

# %% [markdown]
# ## Numerical data

# %%
def numerical(df, column):
    print(df[column].agg(['min','max','mean','median','std','skew']))
    print()
    ## Distribution
    plt.figure(figsize=(15,10))
    ## histogram
    plt.subplot(2,2,1)
    df[column].plot(kind='hist', bins= 10)
    plt.title('Histogram plot')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    ##KDE
    plt.subplot(2,2,2)
    df[column].plot(kind='kde')
    plt.title('KDE plot')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    ##Box plot
    plt.subplot(2,2,3)
    df[column].plot(kind='box')
    plt.title('Box plot')
    ## QQ plot
    plt.subplot(2,2,4)
    stats.probplot(df[column], dist= 'norm', plot= plt)
    plt.title('QQ for Normal Distribution')

# %%
## IQR

def iqr(data,column):
    Q1= data[column].quantile(0.25)
    Q3= data[column].quantile(0.75)
    IQR= Q3- Q1
    lower_bound= Q1 - 1.5 * IQR
    upper_bound= Q3 + 1.5 * IQR
    outlier= data.loc[(data[column] < lower_bound) | (data[column] > upper_bound), column]
    print(len(outlier))

    #plot
    plt.figure(figsize= (9,4))
    data[column].plot(kind='box')
    plt.show()

    return outlier

# %% [markdown]
# ## RATING
#
#
#
# ## COnclusion:- [Adding conclusion is compulsory]

# %%
print(numerical(data,'Rating'))
print('-'*50)
print(iqr(data,'Rating'))
# Out:
# min       3.900000
# max       4.700000
# mean      4.360714
# median    4.400000
# std       0.151031
# skew     -0.274604
# Name: Rating, dtype: float64
#
# None
# --------------------------------------------------
# 70
# 3      4.6
# 8      4.1
# 25     4.6
# 42     4.1
# 64     4.1
#       ...
# 311    4.6
# 313    4.7
# 321    4.0
# 322    4.1
# 324    4.6
# Name: Rating, Length: 70, dtype: float64

# %% [markdown]
# # Screen Size

# %%
## conclusion- > in this column wre have 84 outliers becasue of filling nulls with 0. 
#we should ork in this

# %%
print(numerical(data,'Screen Size'))
print('-'*50)
print(iqr(data,'Screen Size'))
# Out:
# min       0.660000
# max       6.900000
# mean      6.385734
# median    6.700000
# std       1.181944
# skew     -3.989376
# Name: Screen Size, dtype: float64
#
# None
# --------------------------------------------------
# 84
# 9      6.50
# 10     6.50
# 11     6.50
# 21     6.88
# 25     6.10
#        ...
# 313    6.30
# 321    0.66
# 322    1.44
# 324    6.90
# 330    6.10
# Name: Screen Size, Length: 84, dtype: float64

# %% [markdown]
# ### Steps of doing Univariate Analysis on Categorical columns
#
# **Descriptive Statistics**: Compute the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# **Visualizations**: Create visualizations to explore the distribution of the categories. Some common visualizations for categorical data include count plots and pie charts. These visualizations provide a visual representation of the distribution of the categories and can help identify any patterns or anomalies in the data.
#
# **Missing Values**: Check for missing values in the data and decide how to handle them. Missing values can be imputed or excluded from the analysis, depending on the research question and the data set.
#
# **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ## Categorical

# %%
def categorical(data, column_name):
    if column_name in data:
        data[column_name].agg(['count','unique'])
        ##bar plot
        plt.figure(figsize=(8,4))
        data[column_name].value_counts().plot(kind='bar', color= 'green')
        plt.title('Bar plot')
        plt.xlabel(column_name)
        plt.ylabel('Count')
        plt.show()
        ##count plot
        sns.countplot(x=data[column_name])
        plt.xlabel(column_name)
        plt.ylabel('count')
        plt.show()
        ##pie
        plt.figure(figsize=(7,7))
        data[column_name].value_counts().plot(kind= 'pie', autopct="%1.1f%%")
        plt.title('Pie chart')
        plt.show()

# %% [markdown]
# ## RAM

# %%
categorical(data, 'RAM')

# %% [markdown]
# ### Steps of doing Bivariate Analysis
#
# - Select 2 cols
# - Understand type of relationship
#     1. **Numerical - Numerical**<br>
#         a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>
#         b. Check correlation coefficent to check linear relationship
#     2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
#         a. You can plot graphs like barplot, boxplot, kdeplot ,violinplot even scatterplots<br>
#     3. **Categorical - Categorical**<br>
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
#         b. You can plots like heatmap, stacked barplots, treemaps
#
# - Write your conclusions

# %%
print(numerical_columns)
print('-'*50)
print(categorical_columns)
# Out:
# ['Rating', 'Screen Size', 'Battery', 'Price', 'Original_price', 'Discount', 'No_of_rating', 'No_of_review']
# --------------------------------------------------
# ['Brand', 'Model', 'Color', 'Storage', 'RAM', 'ROM', 'rear_camera', 'front_camera']

# %% [markdown]
# ## Cat v/s num

# %%
def cat_num(dataframe, categorical, numerical_columns, head_value= None):
    if head_value:
        top_categories = dataframe[categorical].value_counts(normalize= True).head(head_value).index.tolist()
        dataframe = dataframe[dataframe[categorical].isin(top_categories)]
        #loop over numerical columns
    for num in numerical_columns:
        group_data= dataframe.groupby(categorical)[num].agg(['mean','median','min','max'])
        print(group_data)
        ##plot
        plt.figure(figsize= (15,15))
        plt.subplot(2,2,1)
        #bar plot
        sns.barplot(data= dataframe,y=categorical, x= num)
        plt.title('Bar plot')
        #box plot
        plt.subplot(2,2,2)
        sns.boxplot(y=categorical,x= num, data= dataframe)
        plt.title('BOX plot')
        ## violin plot
        plt.subplot(2,2,3)
        sns.violinplot(y=categorical, x= num, data= dataframe)
        plt.title('Violin Plot')
        ##scatter plot
        plt.subplot(2,2,4)
        sns.scatterplot(x=categorical, y= num,data= dataframe )
        plt.title('Scatterplot')
        plt.xticks(rotation= 45)
        plt.show()

# %%
cat_num(data,'Brand',8)
# Out:
#               mean  median  min  max
# Brand
# apple     4.611765    4.60  4.6  4.7
# cmf       4.400000    4.40  4.4  4.4
# google    4.360000    4.30  4.3  4.6
# infinix   4.311765    4.30  4.2  4.4
# iqoo      4.411111    4.40  4.3  4.5
# itel      4.075000    4.05  4.0  4.2
# kechaoda  4.036364    4.00  4.0  4.1
# lava      4.100000    4.10  4.0  4.2
# motorola  4.323256    4.30  4.2  4.5
# nokia     3.975000    4.00  3.9  4.0
# nothing   4.400000    4.40  4.4  4.4
# oneplus   4.450000    4.40  4.4  4.6
# oppo      4.500000    4.50  4.5  4.5
# poco      4.205882    4.20  4.1  4.3
# realme    4.363934    4.40  4.0  4.5
# redmi     4.276667    4.30  4.2  4.5
# samsung   4.421429    4.40  4.1  4.6
# tecno     4.300000    4.30  4.3  4.3
# vivo      4.483333    4.50  4.4  4.5
#               mean  median       min   max
# Brand
# apple     6.452941   6.700  6.100000  6.90
# cmf       6.670000   6.670  6.670000  6.67
# google    6.140000   6.100  6.100000  6.30
# ...

# %% [markdown]
# ## Num v/s num

# %%
def num_num(df, col1, col2):
    ##plot
    plt.figure(figsize= (15,15))
    plt.subplot(2,2,1)
    ## scatter plot
    sns.scatterplot(data=df, x= col1, y=col2)
    plt.title('Scatterplot')
    print()
    #plt.xticks(rotation= 45)
    ## line plot
    plt.subplot(2,2,2)
    sns.lineplot(data= df, x= col1, y=col2)
    plt.title('Lineplot')
    print()
    ## joint plot
    sns.jointplot(data=df, y= col1, x= col2,kind="hist")
    plt.title('Jointplot')
    print()
    ## pairplot
    sns.pairplot(df[[col1,col2]])
    plt.title('Pairplot')
    plt.show()

# %%
num_num(data,'Price','Original_price')

# %% [markdown]
# # Cat v/s cat

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def cat_n_cat(data, column1, column2, head=10): ## head to get the most frqeuent cat
    # Create a contingency table (cross-tabulation)
    contingency_table = pd.crosstab(data[column1], data[column2])
    
    top_values = contingency_table.sum(axis=1).nlargest(head).index
    contingency_table = contingency_table.loc[top_values]
    
    contingency_table_percent = contingency_table.div(contingency_table.sum(axis=1), axis=0) * 100 # Convert contingency table to percentages
    print(contingency_table_percent)
    plt.figure(figsize=(15, 6))
    
    # Bar plot 
    plt.subplot(1, 2, 1)
    sns.barplot(data=contingency_table_percent.T, orient='h')
    plt.xlabel('Percentage')
    plt.ylabel(f'{column1}')
    plt.title(f'Top {head} Categories in {column1} vs {column2}')
    
    # Heatmap of the percentages
    plt.subplot(1, 2, 2)
    sns.heatmap(contingency_table_percent, annot=True, fmt='.2f', cmap='coolwarm', cbar_kws={'label': 'Percentage'})
    plt.xlabel(f'{column2}')
    plt.ylabel(f'{column1}')
    plt.title(f'Heatmap of {column1} vs {column2}')
    plt.show()

# %%
# RAM and Brand

# %%
cat_n_cat(data,'Brand','RAM')
# Out:
# RAM           0        12        16         3          4          6   \
# Brand
# realme      0.0   8.196721  3.278689  0.000000  16.393443  31.147541
# motorola    0.0  27.906977  0.000000  0.000000  20.930233   0.000000
# apple     100.0   0.000000  0.000000  0.000000   0.000000   0.000000
# infinix     0.0  26.470588  0.000000  8.823529  17.647059   0.000000
# redmi       0.0  10.000000  0.000000  0.000000  26.666667  26.666667
# samsung     0.0  32.142857  0.000000  0.000000  14.285714  25.000000
# oneplus     0.0   9.090909  9.090909  0.000000   0.000000   0.000000
# poco        0.0   5.882353  0.000000  0.000000  52.941176  35.294118
# vivo        0.0   8.333333  0.000000  0.000000   8.333333   8.333333
# kechaoda  100.0   0.000000  0.000000  0.000000   0.000000   0.000000
#
# RAM              8
# Brand
# realme    40.983607
# motorola  51.162791
# apple      0.000000
# infinix   47.058824
# redmi     36.666667
# samsung   28.571429
# oneplus   81.818182
# poco       5.882353
# ...
